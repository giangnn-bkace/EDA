# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline

warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv('./data/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## null values

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## How many survived?

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%', ax=ax[0], shadow=False)
ax[0].set_title("Survived")
ax[0].set_ylabel("")
sns.countplot('Survived', data=data, ax=ax[1])
ax[1].set_title("Survived-num")
plt.show()

# %% [markdown]
# ## Analysing the features

# %% [markdown]
# ### Sex -> Categorical Feature

# %%
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# ### Pclass -> Ordinal Feature

# %%
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_3afc2906_bc6f_11e8_b490_408d5cb25c7arow0_col0 {
#             background-color:  #ffff66;
#         }    #T_3afc2906_bc6f_11e8_b490_408d5cb25c7arow0_col1 {
#             background-color:  #cee666;
#         }    #T_3afc2906_bc6f_11e8_b490_408d5cb25c7arow0_col2 {
#             background-color:  #f4fa66;
#         }    #T_3afc2906_bc6f_11e8_b490_408d5cb25c7arow1_col0 {
#             background-color:  #f6fa66;
#         }    #T_3afc2906_bc6f_11e8_b490_408d5cb25c7arow1_col1 {
#             background-color:  #ffff66;
#         }    #T_3afc2906_bc6f_11e8_b490_408d5cb25c7arow1_col2 {
#             background-color:  #ffff66;
#         }    #T_3afc2906_bc6f_11e8_b490_408d5cb25c7arow2_col0 {
#             background-color:  #60b066;
#         }    #T_3afc2906_bc6f_11e8_b490_408d5cb25c7arow2_col1 {
#             background-color:  #dfef66;
#         }    #T_3afc2906_bc6f_11e8_b490_408d5cb25c7arow2_col2 {
#             background-color:  #90c866;
# ...

# %%
f,ax=plt.subplots(1,3,figsize=(18,8))
data['Pclass'].value_counts(sort=False).plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
(data.groupby(['Pclass'])['Survived'].mean()*100).plot.bar(ax=ax[1])
ax[1].set_title('Survived Percentage by Pclass')
ax[1].set_ylabel('%')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[2])
ax[2].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# ### Sex and Pclass together

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_3b3ee62e_bc6f_11e8_94aa_408d5cb25c7arow0_col0 {
#             background-color:  #ffff66;
#         }    #T_3b3ee62e_bc6f_11e8_94aa_408d5cb25c7arow0_col1 {
#             background-color:  #ffff66;
#         }    #T_3b3ee62e_bc6f_11e8_94aa_408d5cb25c7arow0_col2 {
#             background-color:  #f1f866;
#         }    #T_3b3ee62e_bc6f_11e8_94aa_408d5cb25c7arow0_col3 {
#             background-color:  #ffff66;
#         }    #T_3b3ee62e_bc6f_11e8_94aa_408d5cb25c7arow1_col0 {
#             background-color:  #96cb66;
#         }    #T_3b3ee62e_bc6f_11e8_94aa_408d5cb25c7arow1_col1 {
#             background-color:  #a3d166;
#         }    #T_3b3ee62e_bc6f_11e8_94aa_408d5cb25c7arow1_col2 {
#             background-color:  #f1f866;
#         }    #T_3b3ee62e_bc6f_11e8_94aa_408d5cb25c7arow1_col3 {
#             background-color:  #cfe766;
#         }    #T_3b3ee62e_bc6f_11e8_94aa_408d5cb25c7arow2_col0 {
#             background-color:  #a7d366;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# ### Age -> Continuous Feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,3,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
sns.violinplot("Pclass", "Age", hue="Sex", data=data, split=True, ax=ax[2])
ax[2].set_title("Pclass and Age vs Sex")
ax[2].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# ## Fill in Missing Age values

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations
    
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_3bbd45ca_bc6f_11e8_a31f_408d5cb25c7arow0_col0 {
#             background-color:  #ffff66;
#         }    #T_3bbd45ca_bc6f_11e8_a31f_408d5cb25c7arow0_col1 {
#             background-color:  #ffff66;
#         }    #T_3bbd45ca_bc6f_11e8_a31f_408d5cb25c7arow0_col2 {
#             background-color:  #008066;
#         }    #T_3bbd45ca_bc6f_11e8_a31f_408d5cb25c7arow0_col3 {
#             background-color:  #ffff66;
#         }    #T_3bbd45ca_bc6f_11e8_a31f_408d5cb25c7arow0_col4 {
#             background-color:  #ffff66;
#         }    #T_3bbd45ca_bc6f_11e8_a31f_408d5cb25c7arow0_col5 {
#             background-color:  #ffff66;
#         }    #T_3bbd45ca_bc6f_11e8_a31f_408d5cb25c7arow0_col6 {
#             background-color:  #008066;
#         }    #T_3bbd45ca_bc6f_11e8_a31f_408d5cb25c7arow0_col7 {
#             background-color:  #ffff66;
#         }    #T_3bbd45ca_bc6f_11e8_a31f_408d5cb25c7arow0_col8 {
#             background-color:  #ffff66;
# ...

# %%
# Replacce misspelled initials
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_3bc2f010_bc6f_11e8_ab8a_408d5cb25c7arow0_col0 {
#             background-color:  #ffff66;
#         }    #T_3bc2f010_bc6f_11e8_ab8a_408d5cb25c7arow0_col1 {
#             background-color:  #008066;
#         }    #T_3bc2f010_bc6f_11e8_ab8a_408d5cb25c7arow0_col2 {
#             background-color:  #ffff66;
#         }    #T_3bc2f010_bc6f_11e8_ab8a_408d5cb25c7arow0_col3 {
#             background-color:  #008066;
#         }    #T_3bc2f010_bc6f_11e8_ab8a_408d5cb25c7arow0_col4 {
#             background-color:  #ffff66;
#         }    #T_3bc2f010_bc6f_11e8_ab8a_408d5cb25c7arow1_col0 {
#             background-color:  #008066;
#         }    #T_3bc2f010_bc6f_11e8_ab8a_408d5cb25c7arow1_col1 {
#             background-color:  #ffff66;
#         }    #T_3bc2f010_bc6f_11e8_ab8a_408d5cb25c7arow1_col2 {
#             background-color:  #008066;
#         }    #T_3bc2f010_bc6f_11e8_ab8a_408d5cb25c7arow1_col3 {
#             background-color:  #ffff66;
# ...

# %%
data.groupby(['Initial'])['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
f, ax = plt.subplots(3,1,figsize=(8,18))
data[data['Initial']=="Mr"].Age.plot.hist(ax=ax[0], bins=20, edgecolor='black', color="blue")
ax[0].set_title("Mr")
ax[0].set_xticks(range(0,85,5))
data[data['Initial']=="Mrs"].Age.plot.hist(ax=ax[1], bins=20, edgecolor='black', color="blue")
ax[1].set_title("Mrs")
ax[1].set_xticks(range(0,85,5))
data[data['Initial']=="Miss"].Age.plot.hist(ax=ax[2], bins=20, edgecolor='black', color="blue")
ax[2].set_title("Miss")
ax[2].set_xticks(range(0,85,5))
plt.show()

# %% [markdown]
# ### Filling NaN Ages

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()

# %%
_, ax = plt.subplots()
ax = data[data['Initial']=="Other"]['Pclass'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# ### Embarked -> Categorical Feature

# %%
pd.crosstab([data.Embarked, data.Pclass],[data.Sex, data.Survived], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_3cd3bd30_bc6f_11e8_9217_408d5cb25c7arow0_col0 {
#             background-color:  #fcfe66;
#         }    #T_3cd3bd30_bc6f_11e8_9217_408d5cb25c7arow0_col1 {
#             background-color:  #d2e866;
#         }    #T_3cd3bd30_bc6f_11e8_9217_408d5cb25c7arow0_col2 {
#             background-color:  #f2f866;
#         }    #T_3cd3bd30_bc6f_11e8_9217_408d5cb25c7arow0_col3 {
#             background-color:  #d8ec66;
#         }    #T_3cd3bd30_bc6f_11e8_9217_408d5cb25c7arow0_col4 {
#             background-color:  #e8f466;
#         }    #T_3cd3bd30_bc6f_11e8_9217_408d5cb25c7arow1_col0 {
#             background-color:  #ffff66;
#         }    #T_3cd3bd30_bc6f_11e8_9217_408d5cb25c7arow1_col1 {
#             background-color:  #f9fc66;
#         }    #T_3cd3bd30_bc6f_11e8_9217_408d5cb25c7arow1_col2 {
#             background-color:  #fcfe66;
#         }    #T_3cd3bd30_bc6f_11e8_9217_408d5cb25c7arow1_col3 {
#             background-color:  #fbfd66;
# ...

# %% [markdown]
# #### Chances for survival by port of embarkation

# %%
sns.factorplot('Embarked', 'Survived', data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f, ax = plt.subplots(2,2, figsize=(20,15))
sns.countplot('Embarked', data=data, ax=ax[0,0])
ax[0,0].set_title("No. Of Passengers Boarded")
sns.countplot('Embarked', hue='Sex', data=data, ax=ax[0,1])
ax[0,1].set_title("Male-Female Split for Embarked")
sns.countplot('Embarked', hue='Survived', data=data, ax=ax[1,0])
ax[1,0].set_title("Embarked vs Survived")
sns.countplot('Embarked', hue='Pclass', data=data, ax=ax[1,1])
ax[1,1].set_title("Embarked vs Pclass")
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %% [markdown]
# ## Filling Embarked NaN

# %%
data['Embarked'].fillna('S', inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# ## SibSip -> Discrete Feature

# %%
pd.crosstab(data.SibSp, data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_98e51a68_bc74_11e8_8344_408d5cb25c7arow0_col0 {
#             background-color:  #008066;
#         }    #T_98e51a68_bc74_11e8_8344_408d5cb25c7arow0_col1 {
#             background-color:  #008066;
#         }    #T_98e51a68_bc74_11e8_8344_408d5cb25c7arow1_col0 {
#             background-color:  #c4e266;
#         }    #T_98e51a68_bc74_11e8_8344_408d5cb25c7arow1_col1 {
#             background-color:  #77bb66;
#         }    #T_98e51a68_bc74_11e8_8344_408d5cb25c7arow2_col0 {
#             background-color:  #f9fc66;
#         }    #T_98e51a68_bc74_11e8_8344_408d5cb25c7arow2_col1 {
#             background-color:  #f0f866;
#         }    #T_98e51a68_bc74_11e8_8344_408d5cb25c7arow3_col0 {
#             background-color:  #fbfd66;
#         }    #T_98e51a68_bc74_11e8_8344_408d5cb25c7arow3_col1 {
#             background-color:  #fbfd66;
#         }    #T_98e51a68_bc74_11e8_8344_408d5cb25c7arow4_col0 {
#             background-color:  #f9fc66;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp', 'Survived', data=data, ax=ax[1])
ax[1].set_title("SibSp vs Survived")
plt.close(2)
plt.show()

# %%
pd.crosstab(data.SibSp, data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_f3716938_bc75_11e8_a63d_408d5cb25c7arow0_col0 {
#             background-color:  #008066;
#         }    #T_f3716938_bc75_11e8_a63d_408d5cb25c7arow0_col1 {
#             background-color:  #008066;
#         }    #T_f3716938_bc75_11e8_a63d_408d5cb25c7arow0_col2 {
#             background-color:  #008066;
#         }    #T_f3716938_bc75_11e8_a63d_408d5cb25c7arow1_col0 {
#             background-color:  #7bbd66;
#         }    #T_f3716938_bc75_11e8_a63d_408d5cb25c7arow1_col1 {
#             background-color:  #8ac466;
#         }    #T_f3716938_bc75_11e8_a63d_408d5cb25c7arow1_col2 {
#             background-color:  #c6e266;
#         }    #T_f3716938_bc75_11e8_a63d_408d5cb25c7arow2_col0 {
#             background-color:  #f6fa66;
#         }    #T_f3716938_bc75_11e8_a63d_408d5cb25c7arow2_col1 {
#             background-color:  #eef666;
#         }    #T_f3716938_bc75_11e8_a63d_408d5cb25c7arow2_col2 {
#             background-color:  #f8fc66;
# ...
